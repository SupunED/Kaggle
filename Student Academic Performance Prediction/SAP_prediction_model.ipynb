# %%
import pandas as pd

# %%
data = pd.read_csv('SAP-4000.csv')
df = pd.DataFrame(data)
df.head()
# Out:
#    Gender  HoursStudied/Week Tutoring Region  Attendance(%) Parent Education  \
# 0    Male                5.5       No  Urban           72.7         Tertiary
# 1  Female                6.8       No  Urban           62.0          Primary
# 2  Female                9.7       No  Rural           95.0        Secondary
# 3    Male               13.3      Yes  Rural           52.9              NaN
# 4  Female                8.9       No  Urban           50.8              NaN
#
#    Exam_Score
# 0        43.5
# 1        51.7
# 2        70.1
# 3        79.5
# 4        52.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             4000 non-null   object
#  1   HoursStudied/Week  4000 non-null   float64
#  2   Tutoring           4000 non-null   object
#  3   Region             4000 non-null   object
#  4   Attendance(%)      4000 non-null   float64
#  5   Parent Education   3578 non-null   object
#  6   Exam_Score         4000 non-null   float64
# dtypes: float64(3), object(4)
# memory usage: 218.9+ KB

# %%
df.columns
# Out:
# Index(['Gender', 'HoursStudied/Week', 'Tutoring', 'Region', 'Attendance(%)',
#        'Parent Education', 'Exam_Score'],
#       dtype='object')

# %%
df.describe()
# Out:
#        HoursStudied/Week  Attendance(%)   Exam_Score
# count        4000.000000    4000.000000  4000.000000
# mean            9.861025      75.224150    71.107775
# std             3.713801      14.496906    16.748950
# min             0.000000      50.000000    16.600000
# 25%             7.400000      62.600000    59.300000
# 50%             9.900000      75.600000    71.550000
# 75%            12.600000      87.700000    83.500000
# max            16.000000     100.000000   100.000000

# %%
df['Gender'] = pd.to_numeric(df['Gender'].replace({'Male': 1, 'Female': 0}, regex=True), errors='coerce')
df['Tutoring'] = pd.to_numeric(df['Tutoring'].replace({'Yes': 1, 'No': 0},regex=True), errors='coerce')
df['Region'] = pd.to_numeric(df['Region'].replace({'Rural': 1, 'Urban': 0},regex=True), errors='coerce')
df['Parent Education'] = pd.to_numeric(df['Parent Education'].replace({'None' : 0, 'Primary' : 1, 'Secondary' : 2, 'Tertiary' : 3},regex=True), errors='coerce')
# Out:
# C:\Users\Supun\AppData\Local\Temp\ipykernel_9524\285296080.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender'] = pd.to_numeric(df['Gender'].replace({'Male': 1, 'Female': 0}, regex=True), errors='coerce')
# C:\Users\Supun\AppData\Local\Temp\ipykernel_9524\285296080.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Tutoring'] = pd.to_numeric(df['Tutoring'].replace({'Yes': 1, 'No': 0},regex=True), errors='coerce')
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
y = df['Exam_Score']
features = ['HoursStudied/Week', 'Attendance(%)', 'Region', 'Gender', 'Tutoring', 'Parent Education']
X = df[features]

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
SAP_model = DecisionTreeRegressor()

# %%
SAP_model.fit(train_X, train_y)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.metrics import mean_absolute_error

# %%
print(val_y)
# Out:
# 730     68.0
# 1707    63.2
# 2697    62.4
# 1949    62.7
# 1512    56.6
#         ...
# 618     51.1
# 2363    52.8
# 2987    74.3
# 3658    90.8
# 2310    55.9
# Name: Exam_Score, Length: 1000, dtype: float64

# %%
predictions = SAP_model.predict(val_X)
mae = mean_absolute_error(val_y, predictions)
print(predictions)
# Out:
# [ 64.3  52.1  59.9  60.4  51.5  79.9  58.6  84.8  57.8  61.2  93.4  62.2
#   95.1  78.3  49.9  69.4  69.8  65.1  48.   99.9  68.2  93.5  88.8  64.6
#   80.5  94.   73.5  91.1  69.6  80.2  63.6  94.9  58.3  86.   69.2  60.3
#   70.1  62.4  58.6  94.3  67.5  65.3  98.5  77.  100.   62.2  53.5  76.
#   88.9  31.7  51.3  49.9  84.3  90.7  93.5  59.4  86.7  76.2  25.7  59.3
#   90.3  63.4  74.8  77.7  87.8  75.   69.3  96.8  52.8  86.7  74.9  80.4
#   40.7  63.7  70.7  78.5  80.4  57.8  77.3  58.1  66.1  51.5  68.2  65.9
#   72.   92.4  65.   92.2  66.3  67.3  43.7  63.7  50.1  76.5  69.   41.6
#   76.4  44.1  66.4  70.7  80.   71.   54.9  51.5  74.5  70.2  77.3  56.3
#   45.3  43.3  66.7  83.9  71.7  69.3  91.6  66.   54.4  87.8  91.3 100.
#   49.   69.9  60.8  62.4  79.5  83.1  81.5  51.2  58.7  65.4  43.1  84.3
#   45.8  98.3  60.7  48.7  57.2  65.2  63.1  67.8  54.4  76.   83.6  59.5
#   58.5  60.5  69.3  93.1  62.2  74.6  33.5  46.1  57.8  76.3  55.7  38.3
# ...

# %%
print(f'mean value absolute error = {mae}')
# Out:
# mean value absolute error = 5.7585
